# %%
from operator import index

import kagglehub
from pandas import Series
from pandas.core.interchange.dataframe_protocol import DataFrame
from tensorflow.python.ops.numpy_ops.np_dtypes import int64

#kagglehub.dataset_download("karkavelrajaj/amazon-sales-dataset")
path = kagglehub.dataset_download("karkavelrajaj/amazon-sales-dataset")

# %%
import pandas as pd

product = pd.read_csv(f"{path}/amazon.csv")

# %%
product.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
product.shape
# Out:
# (1465, 16)

# %%
product.tail(5)
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# ...

# %%
product.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
product.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
product.rating_count = product.rating_count.str.replace(',', '').astype(float)
#product.rating_count = product.rating_count.dropna(axis = 0, inplace = True)

# %%
product.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating  rating_count  \
# 0       ₹1,099                 64%    4.2       24269.0
# ...

# %%
product2 = product.copy()

# %%
import numpy as np
product.rating_count = np.trunc(product.rating_count.fillna(0).astype(int))

# %%
product.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1465 non-null   int64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
product.to_csv("product_cleaned.csv", index=False)

# %%
product_cleaned = pd.read_csv("product_cleaned.csv")

# %%
product_cleaned.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating  rating_count  \
# 0       ₹1,099                 64%    4.2         24269
# ...

# %%
int_dtypes = product_cleaned.select_dtypes(include=[np.int64]).columns.tolist()
float_dtypes = product_cleaned.select_dtypes(include=[np.float64]).columns.tolist()
object_dtypes = product_cleaned.select_dtypes(include=[object]).columns.tolist()

print(f"This are the columns with integer datatypes: {int_dtypes}")
print(f"This are the columns with float datatypes: {float_dtypes}")
print(f"This are the columns with object datatypes: {object_dtypes}")
# Out:
# This are the columns with integer datatypes: ['rating_count']
# This are the columns with float datatypes: []
# This are the columns with object datatypes: ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link']

# %%
import pandas as pd
lists = ['a','b','c','d','e','f']
Courses = ["English", "Mathematics", "Science", "Physics", "Geography", "Chemistry"]
ML_names = ["Tom", "Kevin", "Charlie", "Aoife", "Jemima", "Desmond"]
lec = [input(f"what is {Courses} lecturer name?") for Course in Courses]

dic = {"Courses": pd.Series(Courses, index= lists),
       "Module_Leader": pd.Series(ML_names, index= lists),
       "Lecturers": pd.Series(lec, index= lists)}
#Series = pd.Series(lists, )
dic
# Out:
# {'Courses': a        English
#  b    Mathematics
#  c        Science
#  d        Physics
#  e      Geography
#  f      Chemistry
#  dtype: object,
#  'Module_Leader': a        Tom
#  b      Kevin
#  c    Charlie
#  d      Aoife
#  e     Jemima
#  f    Desmond
#  dtype: object,
#  'Lecturers': a    Elijah
#  b     James
#  c     Paula
#  d     Tommy
#  e    Hilger
#  f     Joyee
#  dtype: object}

# %%
dic = pd.DataFrame(dic)
dic
# Out:
#        Courses Module_Leader Lecturers
# a      English           Tom    Elijah
# b  Mathematics         Kevin     James
# c      Science       Charlie     Paula
# d      Physics         Aoife     Tommy
# e    Geography        Jemima    Hilger
# f    Chemistry       Desmond     Joyee

# %%
#return info about geography
dic.loc[['a', 'b', 'c'], ['Courses', 'Module_Leader']]
# Out:
#        Courses Module_Leader
# a      English           Tom
# b  Mathematics         Kevin
# c      Science       Charlie

# %%
dic.iloc[:, [1, 2]]
# Out:
#   Module_Leader Lecturers
# a           Tom    Elijah
# b         Kevin     James
# c       Charlie     Paula
# d         Aoife     Tommy
# e        Jemima    Hilger
# f       Desmond     Joyee

# %%
dic.reset_index(inplace=True)
dic
#dic.rename(columns = {'index': 'Course_Code'}, inplace = True)
# Out:
#   index      Courses Module_Leader Lecturers
# 0     a      English           Tom    Elijah
# 1     b  Mathematics         Kevin     James
# 2     c      Science       Charlie     Paula
# 3     d      Physics         Aoife     Tommy
# 4     e    Geography        Jemima    Hilger
# 5     f    Chemistry       Desmond     Joyee

# %%
dic.rename(columns = {'index': 'Course_Code'}, inplace = True)

# %%
dic
# Out:
#   Course_Code      Courses Module_Leader Lecturers
# 0           a      English           Tom    Elijah
# 1           b  Mathematics         Kevin     James
# 2           c      Science       Charlie     Paula
# 3           d      Physics         Aoife     Tommy
# 4           e    Geography        Jemima    Hilger
# 5           f    Chemistry       Desmond     Joyee

# %%
summary = dic[["Courses", "Lecturers"]].describe(include='all')
summary
# Out:
#         Courses Lecturers
# count         6         6
# unique        6         6
# top     English    Elijah
# freq          1         1

# %%
product_cleaned[["product_name", "rating_count"]].describe(include='all')
# Out:
#                                              product_name   rating_count
# count                                                1465    1465.000000
# unique                                               1337            NaN
# top     Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            NaN
# freq                                                    5            NaN
# mean                                                  NaN   18270.564505
# std                                                   NaN   42729.995315
# min                                                   NaN       0.000000
# 25%                                                   NaN    1173.000000
# 50%                                                   NaN    5178.000000
# 75%                                                   NaN   17325.000000
# max                                                   NaN  426973.000000

# %%
product.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating  rating_count  \
# 0       ₹1,099                 64%    4.2         24269
# ...

# %%
product.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating  rating_count  \
# 0       ₹1,099                 64%    4.2         24269
# ...

# %%
product["actual_price"] = product_cleaned[["actual_price"]].replace(r'\d.', regex=True, inplace=True)
product["discounted_price"] = product_cleaned[["discounted_price"]].replace(r'\d.', regex=True, inplace=True)
product["discounted_price"]
product["actual_price"]
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 1460    None
# 1461    None
# 1462    None
# 1463    None
# 1464    None
# Name: actual_price, Length: 1465, dtype: object

# %%
product.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             None
# 1  Computers&Accessories|Accessories&Peripherals|...             None
# 2  Computers&Accessories|Accessories&Peripherals|...             None
# 3  Computers&Accessories|Accessories&Peripherals|...             None
# 4  Computers&Accessories|Accessories&Peripherals|...             None
#
#   actual_price discount_percentage rating  rating_count  \
# 0         None                 64%    4.2         24269
# ...

# %%
product = product2

# %%
product.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating  rating_count  \
# 0       ₹1,099                 64%    4.2       24269.0
# ...

# %%
product["discounted_price"] = (product["discounted_price"].replace(r'\d.', regex=True)
                               .replace(r"^\s*$", "0", regex=True))
product.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating  rating_count  \
# 0       ₹1,099                 64%    4.2       24269.0
# ...

# %%
#product["discounted_price"]
product["discounted_price"] = (
    product["discounted_price"]
    .astype(str)                          # Ensure it's all strings
    .str.split(r"[^\d.]+")                # Split on any non-digit/non-dot
    .str[-1]                              # Take the last part (number)
    .astype(float)                        # Convert to float
)

# %%
product["discounted_price"]
# Out:
# 0       399.0
# 1       199.0
# 2       199.0
# 3       329.0
# 4       154.0
#         ...
# 1460    379.0
# 1461    280.0
# 1462    219.0
# 1463    399.0
# 1464    863.0
# Name: discounted_price, Length: 1465, dtype: float64

# %%
product["actual_price"] = (product["actual_price"].astype(str).str.split(r"[^\d.]+").str[-1].astype(float))
product.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price discount_percentage rating  rating_count  \
# 0          99.0                 64%    4.2       24269.0
# ...

# %%
import numpy as np
product["rating"] = (pd.to_numeric(product["rating"], errors="coerce").fillna('0').astype(float))
product["rating"]

# %%
product.describe()
# Out:
#        discounted_price  actual_price       rating   rating_count
# count       1465.000000   1465.000000  1465.000000    1463.000000
# mean         497.324526    654.546949     4.093788   18295.541353
# std          294.724753    316.388787     0.310598   42753.864952
# min            0.000000      0.000000     0.000000       2.000000
# 25%          249.000000    400.000000     4.000000    1186.000000
# 50%          449.000000    695.000000     4.100000    5179.000000
# 75%          719.000000    999.000000     4.300000   17336.500000
# max          999.000000    999.000000     5.000000  426973.000000

# %%
filter_out = product[(product["actual_price"]<1000)& (product['discounted_price']> 100) & (product['rating']>4)]
filter_out
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 6     B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7     B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# ...          ...                                                ...
# 1452  B0B8CB7MHW  KNOWZA Electric Handheld Milk Wand Mixer Froth...
# 1455  B00GHL8VP2  USHA 1212 PTC with Adjustable Thermostat Fan H...
# 1457  B00TI8E7BI  Philips HD9306/06 1.5-Litre Electric Kettle (M...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...            399.00
# ...

# %%
Unique_category = list(product["category"].unique())
Unique_category
# Out:
# ['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#  'Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters',
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables',
#  'Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions',
#  'Electronics|HomeTheater,TV&Video|Accessories|RemoteControls',
#  'Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions',
#  'Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts',
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables',
#  'Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts',
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables',
#  'Electronics|HomeTheater,TV&Video|Projectors',
#  'Electronics|HomeAudio|Accessories|Adapters',
#  'Electronics|HomeTheater,TV&Video|SatelliteEquipment|SatelliteReceivers',
# ...

# %%
product["category"].value_counts()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers                                                        1
# ...

# %%
product["category"].value_counts(normalize=True)
#normalize turns the value into percentage
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          0.159044
# Electronics|WearableTechnology|SmartWatches                                                                                0.051877
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                       0.046416
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                              0.043003
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                               0.035495
#                                                                                                                              ...
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers                                                      0.000683
# ...

# %%
(product["category"].value_counts(normalize=True)*100) #so we have it in 100%
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          15.904437
# Electronics|WearableTechnology|SmartWatches                                                                                 5.187713
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        4.641638
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               4.300341
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                3.549488
#                                                                                                                              ...
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers                                                       0.068259
# ...

# %%
#let's round it up to 2 decimal places
round((product["category"].value_counts(normalize=True)*100), 2)
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          15.90
# Electronics|WearableTechnology|SmartWatches                                                                                 5.19
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        4.64
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               4.30
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                3.55
#                                                                                                                            ...
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers                                                       0.07
# ...

# %%
product
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
#let's check if B08Y1TFSP6 is present in the dataset
# let's check if B08Y1TGSP6 is present in the dataset

#create a list

if "B08Y1TFSP6" in product["product_id"]:
    print(" B08Y1TFSP6 is present in the dataset")
else:
    print(" B08Y1TFSP6 is not present in the dataset")
# Out:
#  B08Y1TFSP6 is not present in the dataset

# %%
product_list = product.product_id.tolist()
product_list
# Out:
# ['B07JW9H4J1',
#  'B098NS6PVG',
#  'B096MSW6CT',
#  'B08HDJ86NZ',
#  'B08CF3B7N1',
#  'B08Y1TFSP6',
#  'B08WRWPM22',
#  'B08DDRGWTJ',
#  'B008IFXQFU',
#  'B082LZGK39',
#  'B08CF3D7QR',
#  'B0789LZTCJ',
#  'B07KSMBL2H',
#  'B085DTN6R2',
#  'B09KLVMZ3B',
#  'B083342NKJ',
#  'B0B6F7LX4C',
#  'B082LSVT4B',
#  'B08WRBG3XW',
#  'B08DPLCM6T',
#  'B09C6HXFC1',
#  'B085194JFL',
#  'B09F6S8BT6',
#  'B09NHVCHS9',
#  'B0B1YVCJ2Y',
#  'B01M4GGIVU',
#  'B08B42LWKN',
#  'B094JNXNPV',
#  'B09W5XR9RT',
#  'B077Z65HSD',
#  'B00NH11PEY',
#  'B09CMM3VGK',
#  'B08QSC1XY8',
#  'B008FWZGSG',
#  'B0B4HJNPV4',
#  'B08Y1SJVV5',
#  'B07XLCFSSN',
#  'B09RZS1NQT',
#  'B0B3MMYHYW',
#  'B09C6HWG18',
#  'B00NH11KIK',
#  'B09JPC82QC',
#  'B07JW1Y6XV',
#  'B07KRCW6LZ',
#  'B09NJN8L25',
#  'B07XJYYH7L',
#  'B002PD61Y4',
#  'B014I8SSD0',
#  'B09L8DSSFH',
#  'B07232M876',
#  'B07P681N66',
#  'B0711PVX6Z',
#  'B082T6V3DT',
#  'B07MKFNHKG',
#  'B0BFWGBX61',
#  'B01N90RZ4M',
#  'B0088TKTY2',
#  'B09Q5SWVBJ',
# ...

# %%
if "B08Y1TFSP6" in product_list:
    print(" B08Y1TFSP6 is present in the dataset")
else:
    print(" B08Y1TFSP6 is not present in the dataset")
# Out:
#  B08Y1TFSP6 is present in the dataset

# %%
import numpy as np
product_list = np.array(product_list)
product_lists = product_list[10]
product_lists
"""df = pd.DataFrame(product_list(1,10))
lists = ['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'ninth', 'tenth']
df.index = lists
df"""
# Out:
# "df = pd.DataFrame(product_list(1,10))\nlists = ['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'ninth', 'tenth']\ndf.index = lists\ndf"
